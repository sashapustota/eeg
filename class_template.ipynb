# %%
import os
import numpy as np
import mne
import pandas as pd

# %%
# reading the file & loading in the data
sample_data_folder = mne.datasets.sample.data_path()
sample_data_raw_file = os.path.join(sample_data_folder, 'MEG', 'sample',
                                    'sample_audvis_raw.fif')
raw = mne.io.read_raw_fif(sample_data_raw_file)
raw.info['bads'] = []

raw.load_data()
# Out:
# Opening raw data file /Users/baskakovs/mne_data/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Reading 0 ... 166799  =      0.000 ...   277.714 secs...
# <Raw | sample_audvis_raw.fif, 376 x 166800 (277.7 s), ~481.8 MB, data loaded>

# %% [markdown]
# Looking at the ouput from the load.data() function, try to figure out:
#
# - How many EEG channels?
# - Do you see any EEG channels marked as bad during recording?
# - What is the sampling frequency?
# - How many minutes of data were recorded?

# %%
# selecting only EEG and stimulus data & plotting raw data
raw.pick_types(meg=False, eeg=True, stim=True, exclude=[])
raw.plot();
# Out:
# Opening raw-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# input the name of the bad EEG channel here, e.g. ['EEG 002']
raw.info['bads'] = ['EEG 053']
raw.plot(n_channels=60);
# Out:
# Opening raw-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
from middleware.eeg import EEGReader

eeg_data, headers = EEGReader.read_openbci_txt(file = "./experiments/OpenBCI-RAW-2022-03-22_22-51-41.txt") 
eeg_data.to_csv("./experiments/OpenBCI-RAW-2022-03-22_22-51-41.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000005?line=0'>1</a> from middleware.eeg import EEGReader
#       <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000005?line=2'>3</a> eeg_data, headers = EEGReader.read_openbci_txt(file = "./experiments/OpenBCI-RAW-2022-03-22_22-51-41.txt")
#       <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000005?line=3'>4</a> eeg_data.to_csv("./experiments/OpenBCI-RAW-2022-03-22_22-51-41.csv")
#
# ModuleNotFoundError: No module named 'middleware'

# %%
# using genfromtxt()
arr = np.genfromtxt("OpenBCI-RAW-2022-03-22_22-51-41.csv", delimiter=",")
# using loadtxt()
arr = np.loadtxt("OpenBCI-RAW-2022-03-22_22-51-41.csv", delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb Cell 7' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000006?line=1'>2</a> arr = np.genfromtxt("OpenBCI-RAW-2022-03-22_22-51-41.csv", delimiter=",")
#       <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000006?line=2'>3</a> # using loadtxt()
# ----> <a href='vscode-notebook-cell:/Users/baskakovs/Documents/neurotech/eeg/class_template.ipynb#ch0000006?line=3'>4</a> arr = np.loadtxt("OpenBCI-RAW-2022-03-22_22-51-41.csv", delimiter=",")
#
# File /opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py:1148, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1142'>1143</a> # read data in chunks and fill it into an array via resize
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1143'>1144</a> # over-allocating and shrinking the array later may be faster but is
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1144'>1145</a> # probably not relevant compared to the cost of actually reading and
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1145'>1146</a> # converting the data
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1146'>1147</a> X = None
# -> <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1147'>1148</a> for x in read_data(_loadtxt_chunksize):
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1148'>1149</a>     if X is None:
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1149'>1150</a>         X = np.array(x, dtype)
#
# File /opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py:999, in loadtxt.<locals>.read_data(chunk_size)
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=994'>995</a>     raise ValueError("Wrong number of columns at line %d"
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=995'>996</a>                      % line_num)
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=997'>998</a> # Convert each value according to its column and store
# --> <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=998'>999</a> items = [conv(val) for (conv, val) in zip(converters, vals)]
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1000'>1001</a> # Then pack it according to the dtype's nesting
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1001'>1002</a> items = pack_items(items, packing)
#
# File /opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py:999, in <listcomp>(.0)
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=994'>995</a>     raise ValueError("Wrong number of columns at line %d"
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=995'>996</a>                      % line_num)
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=997'>998</a> # Convert each value according to its column and store
# --> <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=998'>999</a> items = [conv(val) for (conv, val) in zip(converters, vals)]
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1000'>1001</a> # Then pack it according to the dtype's nesting
#    <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=1001'>1002</a> items = pack_items(items, packing)
#
# File /opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py:736, in _getconv.<locals>.floatconv(x)
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=733'>734</a> if '0x' in x:
#     <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=734'>735</a>     return float.fromhex(x)
# --> <a href='file:///opt/miniconda3/envs/neuroexam/lib/python3.9/site-packages/numpy/lib/npyio.py?line=735'>736</a> return float(x)
#
# ValueError: could not convert string to float: ''
